# %%
# !/opt/bin/nvidia-smi
# Out:
# Sat Apr 15 11:54:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.12
# chex                          0.1.7
# click                         8.1.3
# cloudpickle                   2.2.1
# cmake                         3.25.2
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.6.0.post1
# contourpy                     1.0.7
# convertdate                   2.4.0
# cryptography                  40.0.1
# cufflinks                     0.17.3
# cupy-cuda11x                  11.0.0
# cvxopt                        1.3.0
# cvxpy                         1.3.1
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.34
# dask                          2022.12.1
# datascience                   0.17.6
# db-dtypes                     1.1.1
# dbus-python                   1.2.16
# debugpy                       1.6.6
# decorator                     4.4.2
# defusedxml                    0.7.1
# distributed                   2022.12.1
# dlib                          19.24.1
# dm-tree                       0.1.8
# docutils                      0.16
# dopamine-rl                   4.0.6
# earthengine-api               0.1.348
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.6.2
# en-core-web-sm                3.5.0
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.2.0
# etuples                       0.3.8
# exceptiongroup                1.1.1
# fastai                        2.7.12
# fastcore                      1.5.29
# fastdownload                  0.0.7
# fastjsonschema                2.16.3
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# filelock                      3.11.0
# firebase-admin                5.3.0
# Flask                         2.2.3
# flatbuffers                   23.3.3
# flax                          0.6.8
# folium                        0.14.0
# fonttools                     4.39.3
# frozendict                    2.3.7
# fsspec                        2023.4.0
# future                        0.18.3
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.6.6
# gensim                        4.3.1
# geographiclib                 2.0
# geopy                         2.3.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.84.0
# google-auth                   2.17.2
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          1.0.0
# google-cloud-bigquery         3.9.0
# google-cloud-bigquery-storage 2.19.1
# google-cloud-core             2.3.2
# google-cloud-datastore        2.15.1
# google-cloud-firestore        2.11.0
# google-cloud-language         2.9.1
# google-cloud-storage          2.8.0
# google-cloud-translate        3.11.1
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.4.1
# googleapis-common-protos      1.59.0
# googledrivedownloader         0.4
# graphviz                      0.20.1
# greenlet                      2.0.2
# grpcio                        1.53.0
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5netcdf                      1.1.0
# h5py                          3.8.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.22
# holoviews                     1.15.4
# html5lib                      1.1
# httpimport                    1.3.0
# httplib2                      0.21.0
# humanize                      4.6.0
# hyperopt                      0.2.7
# idna                          3.4
# imageio                       2.25.1
# imageio-ffmpeg                0.4.8
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# imgaug                        0.4.0
# importlib-metadata            6.3.0
# importlib-resources           5.12.0
# imutils                       0.5.4
# inflect                       6.0.4
# iniconfig                     2.0.0
# intel-openmp                  2023.1.0
# ipykernel                     5.5.6
# ipython                       7.34.0
# ipython-genutils              0.2.0
# ipython-sql                   0.4.1
# ipywidgets                    7.7.1
# itsdangerous                  2.1.2
# jax                           0.4.8
# jaxlib                        0.4.7+cuda11.cudnn86
# jieba                         0.42.1
# Jinja2                        3.1.2
# joblib                        1.2.0
# jsonpickle                    3.0.1
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.3.0
# jupyter-server                1.23.6
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            3.0.7
# kaggle                        1.5.13
# keras                         2.12.0
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# lazy_loader                   0.2
# libclang                      16.0.0
# librosa                       0.10.0.post2
# lightgbm                      3.3.5
# lit                           16.0.1
# llvmlite                      0.39.1
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.3
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# matplotlib-venn               0.11.9
# mdurl                         0.1.2
# miniKanren                    1.0.3
# missingno                     0.5.2
# mistune                       0.8.4
# mizani                        0.8.1
# mkl                           2019.0
# ml-dtypes                     0.0.4
# mlxtend                       0.14.0
# more-itertools                9.1.0
# moviepy                       1.0.3
# mpmath                        1.3.0
# msgpack                       1.0.5
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       8.1.0
# natsort                       8.3.1
# nbclient                      0.7.3
# nbconvert                     6.5.4
# nbformat                      5.8.0
# nest-asyncio                  1.5.6
# networkx                      3.1
# nibabel                       3.0.2
# nltk                          3.8.1
# notebook                      6.4.8
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.22.4
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# opencv-contrib-python         4.7.0.72
# opencv-python                 4.7.0.72
# opencv-python-headless        4.7.0.72
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optax                         0.1.4
# orbax                         0.1.7
# osqp                          0.6.2.post0
# packaging                     23.0
# palettable                    3.3.1
# pandas                        1.5.3
# pandas-datareader             0.10.0
# pandas-gbq                    0.17.9
# pandocfilters                 1.5.0
# panel                         0.14.4
# param                         1.13.0
# parso                         0.8.3
# partd                         1.3.0
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.4.0
# pip                           23.0.1
# pip-tools                     6.6.2
# platformdirs                  3.2.0
# plotly                        5.13.1
# plotnine                      0.10.1
# pluggy                        1.0.0
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   0.7.2
# proglog                       0.1.10
# progressbar2                  4.2.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                3.0.38
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.20.3
# psutil                        5.9.4
# psycopg2                      2.9.6
# ptyprocess                    0.7.0
# py-cpuinfo                    9.0.0
# py4j                          0.10.9.7
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.7
# pydata-google-auth            1.7.0
# pydot                         1.4.2
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyerfa                        2.0.0.3
# pygame                        2.3.0
# Pygments                      2.14.0
# PyGObject                     3.36.0
# pymc                          5.1.2
# PyMeeus                       0.5.12
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# PySocks                       1.7.1
# pytensor                      2.10.1
# pytest                        7.2.2
# python-apt                    0.0.0
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.1
# python-utils                  3.5.2
# pytz                          2022.7.1
# pytz-deprecation-shim         0.1.0.post0
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.7
# qudida                        0.0.4
# regex                         2022.10.31
# requests                      2.27.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# rich                          13.3.3
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.19.3
# scikit-learn                  1.2.2
# scipy                         1.10.1
# scs                           3.2.3
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# setuptools                    67.6.1
# shapely                       2.0.1
# six                           1.16.0
# sklearn-pandas                2.2.0
# smart-open                    6.3.0
# sniffio                       1.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.4
# soxr                          0.3.5
# spacy                         3.5.1
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    2.0.9
# sqlparse                      0.4.3
# srsly                         2.4.6
# statsmodels                   0.13.5
# sympy                         1.11.1
# tables                        3.8.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.12.1
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.12.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.13.0
# tensorflow-probability        0.19.0
# tensorstore                   0.1.35
# termcolor                     2.2.0
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.17.1
# tf-slim                       1.1.0
# thinc                         8.1.9
# threadpoolctl                 3.1.0
# tifffile                      2023.3.21
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         2.0.0+cu118
# torchaudio                    2.0.1+cu118
# torchdata                     0.6.0
# torchsummary                  1.5.1
# torchtext                     0.15.1
# torchvision                   0.15.1+cu118
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# triton                        2.0.0
# tweepy                        4.13.0
# typer                         0.7.0
# typing_extensions             4.5.0
# tzdata                        2023.3
# tzlocal                       4.3
# uritemplate                   4.1.1
# urllib3                       1.26.15
# vega-datasets                 0.9.0
# wasabi                        1.1.1
# wcwidth                       0.2.6
# webcolors                     1.13
# webencodings                  0.5.1
# websocket-client              1.5.1
# Werkzeug                      2.2.3
# wheel                         0.40.0
# widgetsnbextension            3.6.4
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       1.7.5
# xlrd                          2.0.1
# yellowbrick                   1.5
# yfinance                      0.2.17
# zict                          2.2.0
# zipp                          3.15.0

# %%
# !ln -s /content/drive/MyDrive/unet-pytorch ./
# %cd unet-pytorch/
# !rm -rf ./VOCdevkit
# !unzip ./VOCdevkit.zip -d ./
# !ls
# Out:
# /content/drive/MyDrive/unet-pytorch
# datasets	    nets	      res.jpg	    unet-pytorch.ipynb
# get_miou.py	    predict.py	      summary.py    utils
# img		    __pycache__       test_res.jpg  voc_annotation.py
# json_to_dataset.py  README.md	      train.py	    VOCdevkit
# model_data	    requirements.txt  unet.py	    常见问题汇总.md

# %% [markdown]
# 链接，将训练好的权重保存到云盘里

# %%
# !rm -rf logs
# !mkdir logs

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.2.1
#   Downloading scipy-1.2.1.tar.gz (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 62.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy==1.17.0
#   Downloading numpy-1.17.0.zip (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 83.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib==3.1.2
#   Downloading matplotlib-3.1.2.tar.gz (40.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ERROR: Could not find a version that satisfies the requirement opencv_python==4.1.2.30 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72)
# ERROR: No matching distribution found for opencv_python==4.1.2.30

# %%
#划分训练集和验证集
# !python voc_annotation.py
# Out:
# Generate txt in ImageSets.
# train and val size 29
# traub suze 26
# Generate txt in ImageSets done.
# Check datasets format, this may take a while.
# 检查数据集格式是否符合要求，这可能需要一段时间。
# /content/drive/MyDrive/unet-pytorch/voc_annotation.py:67: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   classes_nums        = np.zeros([256], np.int)
# 100% 29/29 [00:08<00:00,  3.62it/s]
# 打印像素点的值与数量。
# -------------------------------------
# |             Key |           Value |
# -------------------------------------
# |               0 |        31697082 |
# -------------------------------------
# |               1 |         6313798 |
# -------------------------------------
# JPEGImages中的图片应当为.jpg文件、SegmentationClass中的图片应当为.png文件。
# 如果格式有误，参考:
# https://github.com/bubbliiiing/segmentation-format-fix

# %%
# !python train.py
# Out:
# 2023-04-15 11:57:42.439674: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 11:57:43.324072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# initialize network with normal type
# Load weights model_data/unet_vgg_voc.pth.
#
# Successful Load Key: ['vgg.features.0.weight', 'vgg.features.0.bias', 'vgg.features.2.weight', 'vgg.features.2.bias', 'vgg.features.5.weight', 'vgg.features.5.bias', 'vgg.features.7.weight', 'vgg.features.7.bias', 'vgg.features.10.weight', 'vgg.features.10.bias', 'vgg.features.12.weight', 'vgg.features.12.bias', 'vgg.features.14.weight', 'vgg.features.14.bias', 'vgg.features.17.weight', 'vgg.features.17.bias', 'vgg.features.19.weight', 'vgg.features.19.bias', 'vgg.features.21.weight', 'vgg.features.21.bias', 'vgg.fe ……
# Successful Load Key Num: 42
#
# Fail To Load Key: ['final.weight', 'final.bias'] ……
# Fail To Load Key num: 2
#
# 温馨提示，head部分没有载入是正常现象，Backbone部分没有载入是错误的。
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |              num_classes |                                        2|
# |                 backbone |                                      vgg|
# |               model_path |              model_data/unet_vgg_voc.pth|
# |              input_shape |                               [512, 512]|
# |               Init_Epoch |                                        0|
# |             Freeze_Epoch |                                       50|
# |           UnFreeze_Epoch |                                      100|
# |        Freeze_batch_size |                                        2|
# |      Unfreeze_batch_size |                                        2|
# |             Freeze_Train |                                     True|
# |                  Init_lr |                                   0.0001|
# |                   Min_lr |                   1.0000000000000002e-06|
# |           optimizer_type |                                     adam|
# |                 momentum |                                      0.9|
# |            lr_decay_type |                                      cos|
# |              save_period |                                        5|
# |                 save_dir |                                     logs|
# |              num_workers |                                        4|
# |                num_train |                                       26|
# |                  num_val |                                        3|
# ----------------------------------------------------------------------
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Start Train
# Epoch 1/100: 100% 13/13 [00:26<00:00,  2.01s/it, f_score=0.316, lr=1e-5, total_loss=0.783]
# Finish Train
# Start Validation
# Epoch 1/100: 100% 1/1 [00:00<00:00,  1.09it/s, f_score=0.474, lr=1e-5, val_loss=0.635]
# Finish Validation
# Epoch:1/100
# Total Loss: 0.783 || Val Loss: 0.635
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 2/100: 100% 13/13 [00:05<00:00,  2.40it/s, f_score=0.501, lr=2e-5, total_loss=0.464]
# Finish Train
# Start Validation
# Epoch 2/100: 100% 1/1 [00:00<00:00,  1.38it/s, f_score=0.451, lr=2e-5, val_loss=0.477]
# Finish Validation
# Epoch:2/100
# Total Loss: 0.464 || Val Loss: 0.477
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 3/100: 100% 13/13 [00:05<00:00,  2.51it/s, f_score=0.469, lr=5e-5, total_loss=0.36]
# Finish Train
# Start Validation
# Epoch 3/100: 100% 1/1 [00:00<00:00,  1.57it/s, f_score=0.451, lr=5e-5, val_loss=0.536]
# Finish Validation
# Epoch:3/100
# Total Loss: 0.360 || Val Loss: 0.536
# Start Train
# Epoch 4/100: 100% 13/13 [00:05<00:00,  2.38it/s, f_score=0.477, lr=0.0001, total_loss=0.231]
# Finish Train
# Start Validation
# Epoch 4/100: 100% 1/1 [00:00<00:00,  1.71it/s, f_score=0.451, lr=0.0001, val_loss=0.371]
# Finish Validation
# Epoch:4/100
# Total Loss: 0.231 || Val Loss: 0.371
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 5/100: 100% 13/13 [00:05<00:00,  2.49it/s, f_score=0.489, lr=0.0001, total_loss=0.25]
# Finish Train
# Start Validation
# Epoch 5/100: 100% 1/1 [00:00<00:00,  1.72it/s, f_score=0.588, lr=0.0001, val_loss=0.333]
# Finish Validation
# Get miou.
# 100% 3/3 [00:02<00:00,  1.19it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 48.04; mPA: 58.26; Accuracy: 79.18
# Get miou done.
# Epoch:5/100
# Total Loss: 0.250 || Val Loss: 0.333
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 6/100: 100% 13/13 [00:05<00:00,  2.26it/s, f_score=0.657, lr=9.99e-5, total_loss=0.194]
# Finish Train
# Start Validation
# Epoch 6/100: 100% 1/1 [00:00<00:00,  1.64it/s, f_score=0.628, lr=9.99e-5, val_loss=0.3]
# Finish Validation
# Epoch:6/100
# Total Loss: 0.194 || Val Loss: 0.300
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 7/100: 100% 13/13 [00:05<00:00,  2.29it/s, f_score=0.693, lr=9.97e-5, total_loss=0.18]
# Finish Train
# Start Validation
# Epoch 7/100: 100% 1/1 [00:00<00:00,  1.29it/s, f_score=0.751, lr=9.97e-5, val_loss=0.306]
# Finish Validation
# Epoch:7/100
# Total Loss: 0.180 || Val Loss: 0.306
# Start Train
# Epoch 8/100: 100% 13/13 [00:06<00:00,  2.08it/s, f_score=0.72, lr=9.95e-5, total_loss=0.184]
# Finish Train
# Start Validation
# Epoch 8/100: 100% 1/1 [00:00<00:00,  1.63it/s, f_score=0.693, lr=9.95e-5, val_loss=0.319]
# Finish Validation
# Epoch:8/100
# Total Loss: 0.184 || Val Loss: 0.319
# Start Train
# Epoch 9/100: 100% 13/13 [00:05<00:00,  2.34it/s, f_score=0.74, lr=9.93e-5, total_loss=0.204]
# Finish Train
# Start Validation
# Epoch 9/100: 100% 1/1 [00:01<00:00,  1.02s/it, f_score=0.553, lr=9.93e-5, val_loss=0.337]
# Finish Validation
# Epoch:9/100
# Total Loss: 0.204 || Val Loss: 0.337
# Start Train
# Epoch 10/100: 100% 13/13 [00:06<00:00,  2.09it/s, f_score=0.706, lr=9.9e-5, total_loss=0.185]
# Finish Train
# Start Validation
# Epoch 10/100: 100% 1/1 [00:00<00:00,  1.48it/s, f_score=0.777, lr=9.9e-5, val_loss=0.256]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  6.51it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 61.76; mPA: 74.24; Accuracy: 82.71
# Get miou done.
# Epoch:10/100
# Total Loss: 0.185 || Val Loss: 0.256
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 11/100: 100% 13/13 [00:06<00:00,  2.16it/s, f_score=0.768, lr=9.86e-5, total_loss=0.207]
# Finish Train
# Start Validation
# Epoch 11/100: 100% 1/1 [00:01<00:00,  1.16s/it, f_score=0.762, lr=9.86e-5, val_loss=0.294]
# Finish Validation
# Epoch:11/100
# Total Loss: 0.207 || Val Loss: 0.294
# Start Train
# Epoch 12/100: 100% 13/13 [00:05<00:00,  2.26it/s, f_score=0.756, lr=9.82e-5, total_loss=0.149]
# Finish Train
# Start Validation
# Epoch 12/100: 100% 1/1 [00:00<00:00,  1.35it/s, f_score=0.784, lr=9.82e-5, val_loss=0.27]
# Finish Validation
# Epoch:12/100
# Total Loss: 0.149 || Val Loss: 0.270
# Start Train
# Epoch 13/100: 100% 13/13 [00:05<00:00,  2.24it/s, f_score=0.807, lr=9.77e-5, total_loss=0.213]
# Finish Train
# Start Validation
# Epoch 13/100: 100% 1/1 [00:00<00:00,  1.47it/s, f_score=0.714, lr=9.77e-5, val_loss=0.253]
# Finish Validation
# Epoch:13/100
# Total Loss: 0.213 || Val Loss: 0.253
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 14/100: 100% 13/13 [00:05<00:00,  2.30it/s, f_score=0.786, lr=9.71e-5, total_loss=0.197]
# Finish Train
# Start Validation
# Epoch 14/100: 100% 1/1 [00:00<00:00,  1.24it/s, f_score=0.8, lr=9.71e-5, val_loss=0.242]
# Finish Validation
# Epoch:14/100
# Total Loss: 0.197 || Val Loss: 0.242
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 15/100: 100% 13/13 [00:05<00:00,  2.21it/s, f_score=0.82, lr=9.65e-5, total_loss=0.151]
# Finish Train
# Start Validation
# Epoch 15/100: 100% 1/1 [00:00<00:00,  1.28it/s, f_score=0.785, lr=9.65e-5, val_loss=0.253]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  6.38it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 60.04; mPA: 69.47; Accuracy: 84.03
# Get miou done.
# Epoch:15/100
# Total Loss: 0.151 || Val Loss: 0.253
# Start Train
# Epoch 16/100: 100% 13/13 [00:05<00:00,  2.30it/s, f_score=0.806, lr=9.59e-5, total_loss=0.118]
# Finish Train
# Start Validation
# Epoch 16/100: 100% 1/1 [00:00<00:00,  1.44it/s, f_score=0.692, lr=9.59e-5, val_loss=0.298]
# Finish Validation
# Epoch:16/100
# Total Loss: 0.118 || Val Loss: 0.298
# Start Train
# Epoch 17/100: 100% 13/13 [00:06<00:00,  2.08it/s, f_score=0.829, lr=9.52e-5, total_loss=0.167]
# Finish Train
# Start Validation
# Epoch 17/100: 100% 1/1 [00:00<00:00,  1.62it/s, f_score=0.791, lr=9.52e-5, val_loss=0.224]
# Finish Validation
# Epoch:17/100
# Total Loss: 0.167 || Val Loss: 0.224
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 18/100: 100% 13/13 [00:05<00:00,  2.34it/s, f_score=0.765, lr=9.45e-5, total_loss=0.108]
# Finish Train
# Start Validation
# Epoch 18/100: 100% 1/1 [00:00<00:00,  1.49it/s, f_score=0.7, lr=9.45e-5, val_loss=0.283]
# Finish Validation
# Epoch:18/100
# Total Loss: 0.108 || Val Loss: 0.283
# Start Train
# Epoch 19/100: 100% 13/13 [00:06<00:00,  2.04it/s, f_score=0.819, lr=9.36e-5, total_loss=0.128]
# Finish Train
# Start Validation
# Epoch 19/100: 100% 1/1 [00:00<00:00,  1.37it/s, f_score=0.718, lr=9.36e-5, val_loss=0.273]
# Finish Validation
# Epoch:19/100
# Total Loss: 0.128 || Val Loss: 0.273
# Start Train
# Epoch 20/100: 100% 13/13 [00:05<00:00,  2.31it/s, f_score=0.816, lr=9.28e-5, total_loss=0.16]
# Finish Train
# Start Validation
# Epoch 20/100: 100% 1/1 [00:00<00:00,  1.54it/s, f_score=0.84, lr=9.28e-5, val_loss=0.205]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  5.81it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 69.81; mPA: 80.84; Accuracy: 87.12
# Get miou done.
# Epoch:20/100
# Total Loss: 0.160 || Val Loss: 0.205
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 21/100: 100% 13/13 [00:06<00:00,  2.00it/s, f_score=0.844, lr=9.19e-5, total_loss=0.155]
# Finish Train
# Start Validation
# Epoch 21/100: 100% 1/1 [00:00<00:00,  1.05it/s, f_score=0.815, lr=9.19e-5, val_loss=0.212]
# Finish Validation
# Epoch:21/100
# Total Loss: 0.155 || Val Loss: 0.212
# Start Train
# Epoch 22/100: 100% 13/13 [00:05<00:00,  2.33it/s, f_score=0.824, lr=9.09e-5, total_loss=0.125]
# Finish Train
# Start Validation
# Epoch 22/100: 100% 1/1 [00:01<00:00,  1.04s/it, f_score=0.806, lr=9.09e-5, val_loss=0.198]
# Finish Validation
# Epoch:22/100
# Total Loss: 0.125 || Val Loss: 0.198
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 23/100: 100% 13/13 [00:05<00:00,  2.25it/s, f_score=0.827, lr=8.99e-5, total_loss=0.131]
# Finish Train
# Start Validation
# Epoch 23/100: 100% 1/1 [00:00<00:00,  1.17it/s, f_score=0.799, lr=8.99e-5, val_loss=0.196]
# Finish Validation
# Epoch:23/100
# Total Loss: 0.131 || Val Loss: 0.196
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 24/100: 100% 13/13 [00:05<00:00,  2.27it/s, f_score=0.838, lr=8.89e-5, total_loss=0.121]
# Finish Train
# Start Validation
# Epoch 24/100: 100% 1/1 [00:00<00:00,  1.26it/s, f_score=0.82, lr=8.89e-5, val_loss=0.207]
# Finish Validation
# Epoch:24/100
# Total Loss: 0.121 || Val Loss: 0.207
# Start Train
# Epoch 25/100: 100% 13/13 [00:05<00:00,  2.19it/s, f_score=0.842, lr=8.78e-5, total_loss=0.138]
# Finish Train
# Start Validation
# Epoch 25/100: 100% 1/1 [00:00<00:00,  1.40it/s, f_score=0.728, lr=8.78e-5, val_loss=0.264]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  6.20it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 65.95; mPA: 74.91; Accuracy: 86.46
# Get miou done.
# Epoch:25/100
# Total Loss: 0.138 || Val Loss: 0.264
# Start Train
# Epoch 26/100: 100% 13/13 [00:05<00:00,  2.23it/s, f_score=0.852, lr=8.67e-5, total_loss=0.102]
# Finish Train
# Start Validation
# Epoch 26/100: 100% 1/1 [00:00<00:00,  1.45it/s, f_score=0.829, lr=8.67e-5, val_loss=0.192]
# Finish Validation
# Epoch:26/100
# Total Loss: 0.102 || Val Loss: 0.192
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 27/100: 100% 13/13 [00:06<00:00,  2.16it/s, f_score=0.841, lr=8.55e-5, total_loss=0.115]
# Finish Train
# Start Validation
# Epoch 27/100: 100% 1/1 [00:00<00:00,  1.35it/s, f_score=0.787, lr=8.55e-5, val_loss=0.199]
# Finish Validation
# Epoch:27/100
# Total Loss: 0.115 || Val Loss: 0.199
# Start Train
# Epoch 28/100: 100% 13/13 [00:06<00:00,  2.00it/s, f_score=0.834, lr=8.43e-5, total_loss=0.145]
# Finish Train
# Start Validation
# Epoch 28/100: 100% 1/1 [00:00<00:00,  1.36it/s, f_score=0.821, lr=8.43e-5, val_loss=0.19]
# Finish Validation
# Epoch:28/100
# Total Loss: 0.145 || Val Loss: 0.190
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 29/100: 100% 13/13 [00:05<00:00,  2.27it/s, f_score=0.847, lr=8.3e-5, total_loss=0.11]
# Finish Train
# Start Validation
# Epoch 29/100: 100% 1/1 [00:00<00:00,  1.18it/s, f_score=0.821, lr=8.3e-5, val_loss=0.181]
# Finish Validation
# Epoch:29/100
# Total Loss: 0.110 || Val Loss: 0.181
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 30/100: 100% 13/13 [00:06<00:00,  2.02it/s, f_score=0.862, lr=8.17e-5, total_loss=0.128]
# Finish Train
# Start Validation
# Epoch 30/100: 100% 1/1 [00:00<00:00,  1.23it/s, f_score=0.745, lr=8.17e-5, val_loss=0.264]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  5.27it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 66.64; mPA: 74.83; Accuracy: 87.12
# Get miou done.
# Epoch:30/100
# Total Loss: 0.128 || Val Loss: 0.264
# Start Train
# Epoch 31/100: 100% 13/13 [00:06<00:00,  2.17it/s, f_score=0.852, lr=8.04e-5, total_loss=0.154]
# Finish Train
# Start Validation
# Epoch 31/100: 100% 1/1 [00:01<00:00,  1.17s/it, f_score=0.758, lr=8.04e-5, val_loss=0.258]
# Finish Validation
# Epoch:31/100
# Total Loss: 0.154 || Val Loss: 0.258
# Start Train
# Epoch 32/100: 100% 13/13 [00:05<00:00,  2.22it/s, f_score=0.848, lr=7.9e-5, total_loss=0.125]
# Finish Train
# Start Validation
# Epoch 32/100: 100% 1/1 [00:00<00:00,  1.30it/s, f_score=0.849, lr=7.9e-5, val_loss=0.185]
# Finish Validation
# Epoch:32/100
# Total Loss: 0.125 || Val Loss: 0.185
# Start Train
# Epoch 33/100: 100% 13/13 [00:05<00:00,  2.25it/s, f_score=0.85, lr=7.76e-5, total_loss=0.127]
# Finish Train
# Start Validation
# Epoch 33/100: 100% 1/1 [00:00<00:00,  1.10it/s, f_score=0.807, lr=7.76e-5, val_loss=0.257]
# Finish Validation
# Epoch:33/100
# Total Loss: 0.127 || Val Loss: 0.257
# Start Train
# Epoch 34/100: 100% 13/13 [00:05<00:00,  2.33it/s, f_score=0.85, lr=7.62e-5, total_loss=0.138]
# Finish Train
# Start Validation
# Epoch 34/100: 100% 1/1 [00:00<00:00,  1.59it/s, f_score=0.816, lr=7.62e-5, val_loss=0.205]
# Finish Validation
# Epoch:34/100
# Total Loss: 0.138 || Val Loss: 0.205
# Start Train
# Epoch 35/100: 100% 13/13 [00:05<00:00,  2.25it/s, f_score=0.858, lr=7.48e-5, total_loss=0.119]
# Finish Train
# Start Validation
# Epoch 35/100: 100% 1/1 [00:01<00:00,  1.05s/it, f_score=0.778, lr=7.48e-5, val_loss=0.269]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  6.58it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 70.58; mPA: 80.1; Accuracy: 87.98
# Get miou done.
# Epoch:35/100
# Total Loss: 0.119 || Val Loss: 0.269
# Start Train
# Epoch 36/100: 100% 13/13 [00:05<00:00,  2.26it/s, f_score=0.841, lr=7.33e-5, total_loss=0.149]
# Finish Train
# Start Validation
# Epoch 36/100: 100% 1/1 [00:00<00:00,  1.57it/s, f_score=0.736, lr=7.33e-5, val_loss=0.288]
# Finish Validation
# Epoch:36/100
# Total Loss: 0.149 || Val Loss: 0.288
# Start Train
# Epoch 37/100: 100% 13/13 [00:05<00:00,  2.23it/s, f_score=0.875, lr=7.18e-5, total_loss=0.111]
# Finish Train
# Start Validation
# Epoch 37/100: 100% 1/1 [00:00<00:00,  1.40it/s, f_score=0.822, lr=7.18e-5, val_loss=0.186]
# Finish Validation
# Epoch:37/100
# Total Loss: 0.111 || Val Loss: 0.186
# Start Train
# Epoch 38/100: 100% 13/13 [00:05<00:00,  2.26it/s, f_score=0.848, lr=7.02e-5, total_loss=0.114]
# Finish Train
# Start Validation
# Epoch 38/100: 100% 1/1 [00:00<00:00,  1.54it/s, f_score=0.748, lr=7.02e-5, val_loss=0.281]
# Finish Validation
# Epoch:38/100
# Total Loss: 0.114 || Val Loss: 0.281
# Start Train
# Epoch 39/100: 100% 13/13 [00:05<00:00,  2.25it/s, f_score=0.871, lr=6.87e-5, total_loss=0.108]
# Finish Train
# Start Validation
# Epoch 39/100: 100% 1/1 [00:00<00:00,  1.55it/s, f_score=0.867, lr=6.87e-5, val_loss=0.17]
# Finish Validation
# Epoch:39/100
# Total Loss: 0.108 || Val Loss: 0.170
# Save best model to best_epoch_weights.pth
# Start Train
# Epoch 40/100: 100% 13/13 [00:05<00:00,  2.25it/s, f_score=0.857, lr=6.71e-5, total_loss=0.104]
# Finish Train
# Start Validation
# Epoch 40/100: 100% 1/1 [00:00<00:00,  1.44it/s, f_score=0.87, lr=6.71e-5, val_loss=0.174]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  4.80it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 71.28; mPA: 79.93; Accuracy: 88.57
# Get miou done.
# Epoch:40/100
# Total Loss: 0.104 || Val Loss: 0.174
# Start Train
# Epoch 41/100: 100% 13/13 [00:06<00:00,  1.94it/s, f_score=0.887, lr=6.55e-5, total_loss=0.0976]
# Finish Train
# Start Validation
# Epoch 41/100: 100% 1/1 [00:00<00:00,  1.48it/s, f_score=0.856, lr=6.55e-5, val_loss=0.189]
# Finish Validation
# Epoch:41/100
# Total Loss: 0.098 || Val Loss: 0.189
# Start Train
# Epoch 42/100: 100% 13/13 [00:05<00:00,  2.17it/s, f_score=0.881, lr=6.39e-5, total_loss=0.104]
# Finish Train
# Start Validation
# Epoch 42/100: 100% 1/1 [00:00<00:00,  1.08it/s, f_score=0.767, lr=6.39e-5, val_loss=0.258]
# Finish Validation
# Epoch:42/100
# Total Loss: 0.104 || Val Loss: 0.258
# Start Train
# Epoch 43/100: 100% 13/13 [00:06<00:00,  1.95it/s, f_score=0.869, lr=6.22e-5, total_loss=0.104]
# Finish Train
# Start Validation
# Epoch 43/100: 100% 1/1 [00:00<00:00,  1.45it/s, f_score=0.826, lr=6.22e-5, val_loss=0.189]
# Finish Validation
# Epoch:43/100
# Total Loss: 0.104 || Val Loss: 0.189
# Start Train
# Epoch 44/100: 100% 13/13 [00:06<00:00,  2.13it/s, f_score=0.86, lr=6.06e-5, total_loss=0.121]
# Finish Train
# Start Validation
# Epoch 44/100: 100% 1/1 [00:01<00:00,  1.02s/it, f_score=0.845, lr=6.06e-5, val_loss=0.175]
# Finish Validation
# Epoch:44/100
# Total Loss: 0.121 || Val Loss: 0.175
# Start Train
# Epoch 45/100: 100% 13/13 [00:06<00:00,  2.17it/s, f_score=0.865, lr=5.89e-5, total_loss=0.115]
# Finish Train
# Start Validation
# Epoch 45/100: 100% 1/1 [00:00<00:00,  1.53it/s, f_score=0.867, lr=5.89e-5, val_loss=0.175]
# Finish Validation
# Get miou.
# 100% 3/3 [00:00<00:00,  5.53it/s]
# Calculate miou.
# Num classes 2
# ===> mIoU: 69.65; mPA: 77.46; Accuracy: 88.32
# Get miou done.
# Epoch:45/100
# Total Loss: 0.115 || Val Loss: 0.175
# Start Train
# Epoch 46/100: 100% 13/13 [00:05<00:00,  2.19it/s, f_score=0.866, lr=5.72e-5, total_loss=0.105]
# Finish Train
# Start Validation
# Epoch 46/100: 100% 1/1 [00:00<00:00,  1.60it/s, f_score=0.823, lr=5.72e-5, val_loss=0.191]
# Finish Validation
# Epoch:46/100
# Total Loss: 0.105 || Val Loss: 0.191
# Start Train
# Epoch 47/100:  92% 12/13 [00:05<00:00,  2.63it/s, f_score=0.871, lr=5.56e-5, total_loss=0.125]

# %% [markdown]
# # 预测

# %%
#修改unet.py文件中的model_path和num_classes
# !python predict.py
# Out:
# logs/best_epoch_weights.pth model, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path |              logs/best_epoch_weights.pth|
# |              num_classes |                                        2|
# |                 backbone |                                      vgg|
# |              input_shape |                               [512, 512]|
# |                    blend |                                     True|
# |                 mix_type |                                        0|
# |                     cuda |                                     True|
# ----------------------------------------------------------------------
# Input image filename:img/718.jpg
# Input image filename:
# ^C
